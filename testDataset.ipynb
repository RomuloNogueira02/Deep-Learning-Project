# %%
from poolDatasetV2 import PoolDatasetV2
import os
from torchvision.transforms import v2
import torch
from helpers import *
import random

# %%
transforms = v2.Compose([
    v2.Resize((224, 224)),
    v2.ToImage(),
    #v2.RandomHorizontalFlip(p=1),
    v2.ToDtype(torch.float32, scale=True),
    #v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

ROOT_DIR = os.getcwd() + "\\dataset\\images"

ds = PoolDatasetV2(ROOT_DIR, transforms)

# %%
# Print some random images with or without labels
list_indexes = range(len(ds))
list_indexes = random.sample(list_indexes, 5)
print(list_indexes)
for i in list_indexes:
    img, label = ds[i]
    
    if len(label) > 0:
        print(str(i) + " have label")
        show_image_with_box(img, label)
    else:
        print(str(i) + " does not have label")
        show_image(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# [232, 5662, 855, 1751, 5690]
# 232 have label
# 5662 does not have label
# 855 does not have label
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1751 have label
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 5690 have label
